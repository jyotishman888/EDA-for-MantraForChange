# 32              revision with the help of test
# 33                                     Not any
# 34                                     Not any
# 35                                      Paper
# 36                                     Not any
# 37                                     Not any
# 38                                     Not any
# 39                                     Not any
# 40                      Yrs about activity sci
# 41                  participants are satisfied
# 42                  Participants are satisfied
# 43                        Yes,we can do better
# 44                Improve the punjabi language
# 45                                         Yes
# 46                      Refreshing activities
# 47                                         Yes
# 48                       When we take feedback
# 49                      They are all satisfied
# 50                                         Yes
# 51                                         Yes
# 52                                         yes
# 53                                         Yes
# 54         There should be trainings like this
# 55                                     Nothing

# %%
df = df.dropna(how='any',axis=0)

# %%
df.isnull().sum()
# Out:
# Question    0
# Response    0
# dtype: int64

# %%
df[df['Response'].str.isalnum()]
# Out:
#                                              Question Response
# 16  Were there any good suggestions given by the p...       Ok
# 45  Were there any good suggestions given by the p...      Yes
# 47  Were there any good suggestions given by the p...      Yes
# 50  Were there any good suggestions given by the p...      Yes
# 51  Were there any good suggestions given by the p...      Yes
# 52  Were there any good suggestions given by the p...      yes
# 53  Were there any good suggestions given by the p...      Yes
# 55  Were there any good suggestions given by the p...  Nothing

# %%
Responses = df.Response.str.cat(sep='/')
tokens = word_tokenize(Responses)

filtered_sentence = []
stop_words = set(stopwords.words('english'))

for w in tokens:
    if w not in stop_words:
        filtered_sentence.append(w)
        
print(filtered_sentence)
# Out:
# ['Students', 'good/Not', 'any/Not', 'any/Not', 'any/Not', 'any/Grammar', '/Not', 'any/Not', 'any/Not', 'any/Not', 'any/Teachers', 'hard', 'working', '/Not', 'any/Not', 'any/Personal', 'attention', 'given./Not', 'any/Not', 'any/Ok/Yes./Planned', 'extra', 'class', 'curriculum/Tea', '/Not', 'any/Not', 'any/Keep', 'motivating', 'students', 'mission', '100', '%', './Not', 'any/Not', 'any/Not', 'any/Not', 'any/Not', 'any/Not', 'any/Not', 'any/Not', 'any/Grammar', 'works', '/revision', 'help', 'test/Not', 'any/Not', 'any/Paper', '/Not', 'any/Not', 'any/Not', 'any/Not', 'any/Yrs', 'activity', 'sci/participants', 'satisfied/Participants', 'satisfied/Yes', ',', 'better/Improve', 'punjabi', 'language/Yes/Refreshing', 'activities', '/Yes/When', 'take', 'feedback/They', 'satisfied/Yes/Yes/yes/Yes/There', 'trainings', 'like', 'this/Nothing']

# %%
import time
item_list = filtered_sentence
new_list = []
for e in item_list:
    if e not in ('No', 'Yes','na','Nil','None','Not','nil','Nill','NIL','Ok','NO','YES','NA','na','none','Na','.','Ni','N.A','nul','Regarding','regarding'):
        new_list.append(e)
item_list = new_list

# %%
print(new_list)
# Out:
# ['Students', 'good/Not', 'any/Not', 'any/Not', 'any/Not', 'any/Grammar', '/Not', 'any/Not', 'any/Not', 'any/Not', 'any/Teachers', 'hard', 'working', '/Not', 'any/Not', 'any/Personal', 'attention', 'given./Not', 'any/Not', 'any/Ok/Yes./Planned', 'extra', 'class', 'curriculum/Tea', '/Not', 'any/Not', 'any/Keep', 'motivating', 'students', 'mission', '100', '%', './Not', 'any/Not', 'any/Not', 'any/Not', 'any/Not', 'any/Not', 'any/Not', 'any/Not', 'any/Grammar', 'works', '/revision', 'help', 'test/Not', 'any/Not', 'any/Paper', '/Not', 'any/Not', 'any/Not', 'any/Not', 'any/Yrs', 'activity', 'sci/participants', 'satisfied/Participants', 'satisfied/Yes', ',', 'better/Improve', 'punjabi', 'language/Yes/Refreshing', 'activities', '/Yes/When', 'take', 'feedback/They', 'satisfied/Yes/Yes/yes/Yes/There', 'trainings', 'like', 'this/Nothing']

# %%
s = new_list
listToStr = ' '.join(map(str, s))
#a, b = listToStr.split('/////')
#print(a)
#print(b)
split_up = [s.strip() for s in listToStr.split('/')]
print(split_up)
# Out:
# ['Students good', 'Not any', 'Not any', 'Not any', 'Not any', 'Grammar', 'Not any', 'Not any', 'Not any', 'Not any', 'Teachers hard working', 'Not any', 'Not any', 'Personal attention given.', 'Not any', 'Not any', 'Ok', 'Yes.', 'Planned extra class curriculum', 'Tea', 'Not any', 'Not any', 'Keep motivating students mission 100 % .', 'Not any', 'Not any', 'Not any', 'Not any', 'Not any', 'Not any', 'Not any', 'Not any', 'Grammar works', 'revision help test', 'Not any', 'Not any', 'Paper', 'Not any', 'Not any', 'Not any', 'Not any', 'Yrs activity sci', 'participants satisfied', 'Participants satisfied', 'Yes , better', 'Improve punjabi language', 'Yes', 'Refreshing activities', 'Yes', 'When take feedback', 'They satisfied', 'Yes', 'Yes', 'yes', 'Yes', 'There trainings like this', 'Nothing']

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

lem_sent = [lemmatizer.lemmatize(s) for s in split_up]
print(lem_sent)
# Out:
# ['Students good', 'Not any', 'Not any', 'Not any', 'Not any', 'Grammar', 'Not any', 'Not any', 'Not any', 'Not any', 'Teachers hard working', 'Not any', 'Not any', 'Personal attention given.', 'Not any', 'Not any', 'Ok', 'Yes.', 'Planned extra class curriculum', 'Tea', 'Not any', 'Not any', 'Keep motivating students mission 100 % .', 'Not any', 'Not any', 'Not any', 'Not any', 'Not any', 'Not any', 'Not any', 'Not any', 'Grammar works', 'revision help test', 'Not any', 'Not any', 'Paper', 'Not any', 'Not any', 'Not any', 'Not any', 'Yrs activity sci', 'participants satisfied', 'Participants satisfied', 'Yes , better', 'Improve punjabi language', 'Yes', 'Refreshing activities', 'Yes', 'When take feedback', 'They satisfied', 'Yes', 'Yes', 'yes', 'Yes', 'There trainings like this', 'Nothing']

# %%
import nltk
from nltk.tokenize import word_tokenize


frequency_dist = nltk.FreqDist(lem_sent)
sorted(frequency_dist,key=frequency_dist.__getitem__, reverse=True)[0:20]
# Out:
# ['Not any',
#  'Yes',
#  'Students good',
#  'Grammar',
#  'Teachers hard working',
#  'Personal attention given.',
#  'Ok',
#  'Yes.',
#  'Planned extra class curriculum',
#  'Tea',
#  'Keep motivating students mission 100 % .',
#  'Grammar works',
#  'revision help test',
#  'Paper',
#  'Yrs activity sci',
#  'participants satisfied',
#  'Participants satisfied',
#  'Yes , better',
#  'Improve punjabi language',
#  'Refreshing activities']
